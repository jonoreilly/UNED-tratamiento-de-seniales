# %% [markdown]
# ## Grabacion

# %% [markdown]
# ### Instalar dependencias

# %%
using Pkg
Pkg.add("WAV")
# Out:
#    Resolving package versions...
#      Project No packages added to or removed from `C:\Users\jonor\.julia\environments\v1.12\Project.toml`
#     Manifest No packages added to or removed from `C:\Users\jonor\.julia\environments\v1.12\Manifest.toml`

# %% [markdown]
# ### Grabar audio

# %% [markdown]
# ### Reproducir audio

# %%
using WAV
y, fs = wavread(raw"C:\Windows\Media\Ring01.wav")
wavplay(y, fs)
